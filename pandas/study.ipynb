# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_excel('post_details (1).xlsx')

# %%
data
# Out:
#                       Circle                 Division                 Office  \
# 0      Andhra Pradesh Circle      Amalapuram Division     Antarvedipalem S.O
# 1      Andhra Pradesh Circle      Amalapuram Division  Appanaramunilanka B.O
# 2      Andhra Pradesh Circle      Amalapuram Division        Atreyapuram S.O
# 3      Andhra Pradesh Circle      Amalapuram Division        Balusutippa B.O
# 4      Andhra Pradesh Circle      Amalapuram Division       Battucheruvu B.O
# ...                      ...                      ...                    ...
# 43608     West Bengal Circle  Uttar Dinajpur Division              Tarial BO
# 43609     West Bengal Circle  Uttar Dinajpur Division          Thakurbari BO
# 43610     West Bengal Circle  Uttar Dinajpur Division          Thakurbari BO
# 43611     West Bengal Circle  Uttar Dinajpur Division     Tungail Bilpara BO
# 43612     West Bengal Circle  Uttar Dinajpur Division          Tungidighi BO
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#                   Circle             Division                 Office  \
# 0  Andhra Pradesh Circle  Amalapuram Division     Antarvedipalem S.O
# 1  Andhra Pradesh Circle  Amalapuram Division  Appanaramunilanka B.O
# 2  Andhra Pradesh Circle  Amalapuram Division        Atreyapuram S.O
# 3  Andhra Pradesh Circle  Amalapuram Division        Balusutippa B.O
# 4  Andhra Pradesh Circle  Amalapuram Division       Battucheruvu B.O
#
#        Post Community  Post_Slab  No_Of_Posts Language_Name Pincode
# 0  Daksevak       EWS      10000            1        Telugu  533252
# 1       BPM        SC      12000            1        Telugu  533252
# 2  Daksevak     PWD-A      10000            1        Telugu  533235
# 3       BPM        ST      12000            1        Telugu  533212
# 4      ABPM       EWS      10000            1        Telugu  533212

# %%
data.head(10)
# Out:
#                   Circle             Division                 Office  \
# 0  Andhra Pradesh Circle  Amalapuram Division     Antarvedipalem S.O
# 1  Andhra Pradesh Circle  Amalapuram Division  Appanaramunilanka B.O
# 2  Andhra Pradesh Circle  Amalapuram Division        Atreyapuram S.O
# 3  Andhra Pradesh Circle  Amalapuram Division        Balusutippa B.O
# 4  Andhra Pradesh Circle  Amalapuram Division       Battucheruvu B.O
# 5  Andhra Pradesh Circle  Amalapuram Division        Challapalli B.O
# 6  Andhra Pradesh Circle  Amalapuram Division          Goditippa B.O
# 7  Andhra Pradesh Circle  Amalapuram Division              Gondi B.O
# 8  Andhra Pradesh Circle  Amalapuram Division            Idarada B.O
# 9  Andhra Pradesh Circle  Amalapuram Division           Karavaka B.O
#
#        Post Community  Post_Slab  No_Of_Posts Language_Name Pincode
# 0  Daksevak       EWS      10000            1        Telugu  533252
# 1       BPM        SC      12000            1        Telugu  533252
# ...

# %%
data.tail(6)
# Out:
#                    Circle                 Division              Office  Post  \
# 43607  West Bengal Circle  Uttar Dinajpur Division         Taherpur BO  ABPM
# 43608  West Bengal Circle  Uttar Dinajpur Division           Tarial BO   BPM
# 43609  West Bengal Circle  Uttar Dinajpur Division       Thakurbari BO  ABPM
# 43610  West Bengal Circle  Uttar Dinajpur Division       Thakurbari BO  ABPM
# 43611  West Bengal Circle  Uttar Dinajpur Division  Tungail Bilpara BO  ABPM
# 43612  West Bengal Circle  Uttar Dinajpur Division       Tungidighi BO   BPM
#
#       Community  Post_Slab  No_Of_Posts Language_Name Pincode
# 43607        UR      10000            1       Bengali  733123
# 43608        UR      12000            1       Bengali  733208
# 43609       EWS      10000            1       Bengali  733208
# 43610       OBC      10000            1       Bengali  733208
# 43611        SC      10000            1       Bengali  733129
# ...

# %%
data.shape
# Out:
# (43613, 9)

# %%
data .info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43613 entries, 0 to 43612
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Circle         43613 non-null  object
#  1   Division       43613 non-null  object
#  2   Office         43613 non-null  object
#  3   Post           43613 non-null  object
#  4   Community      43613 non-null  object
#  5   Post_Slab      43613 non-null  int64
#  6   No_Of_Posts    43613 non-null  int64
#  7   Language_Name  43613 non-null  object
#  8   Pincode        43613 non-null  object
# dtypes: int64(2), object(7)
# memory usage: 3.0+ MB

# %%
  data.describe()
# Out:
#           Post_Slab   No_Of_Posts
# count  43613.000000  43613.000000
# mean   10779.079632      1.014101
# std      975.303031      0.134447
# min    10000.000000      1.000000
# 25%    10000.000000      1.000000
# 50%    10000.000000      1.000000
# 75%    12000.000000      1.000000
# max    12000.000000      9.000000

# %%
data['Circle']
# Out:
# 0        Andhra Pradesh Circle
# 1        Andhra Pradesh Circle
# 2        Andhra Pradesh Circle
# 3        Andhra Pradesh Circle
# 4        Andhra Pradesh Circle
#                  ...
# 43608       West Bengal Circle
# 43609       West Bengal Circle
# 43610       West Bengal Circle
# 43611       West Bengal Circle
# 43612       West Bengal Circle
# Name: Circle, Length: 43613, dtype: object

# %%
type(data['Circle'])
# Out:
# pandas.core.series.Series

# %%
data[['Circle','Community','Post_Slab']].head()
# Out:
#                   Circle Community  Post_Slab
# 0  Andhra Pradesh Circle       EWS      10000
# 1  Andhra Pradesh Circle        SC      12000
# 2  Andhra Pradesh Circle     PWD-A      10000
# 3  Andhra Pradesh Circle        ST      12000
# 4  Andhra Pradesh Circle       EWS      10000

# %%
data.iloc[1:3]
# Out:
#                   Circle             Division                 Office  \
# 1  Andhra Pradesh Circle  Amalapuram Division  Appanaramunilanka B.O
# 2  Andhra Pradesh Circle  Amalapuram Division        Atreyapuram S.O
#
#        Post Community  Post_Slab  No_Of_Posts Language_Name Pincode
# 1       BPM        SC      12000            1        Telugu  533252
# 2  Daksevak     PWD-A      10000            1        Telugu  533235

# %%
mask = data['Circle']=='Andhra Pradesh Circle'

# %%
mask
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 43608    False
# 43609    False
# 43610    False
# 43611    False
# 43612    False
# Name: Circle, Length: 43613, dtype: bool

# %%
data[mask]
# Out:
#                      Circle               Division                 Office  \
# 0     Andhra Pradesh Circle    Amalapuram Division     Antarvedipalem S.O
# 1     Andhra Pradesh Circle    Amalapuram Division  Appanaramunilanka B.O
# 2     Andhra Pradesh Circle    Amalapuram Division        Atreyapuram S.O
# 3     Andhra Pradesh Circle    Amalapuram Division        Balusutippa B.O
# 4     Andhra Pradesh Circle    Amalapuram Division       Battucheruvu B.O
# ...                     ...                    ...                    ...
# 1346  Andhra Pradesh Circle  Vizianagaram Division          Siripuram B.O
# 1347  Andhra Pradesh Circle  Vizianagaram Division          Tanavaram B.O
# 1348  Andhra Pradesh Circle  Vizianagaram Division           Tettangi B.O
# 1349  Andhra Pradesh Circle  Vizianagaram Division               VENNE BO
# 1350  Andhra Pradesh Circle  Vizianagaram Division        Y S R Puram B.O
#
#           Post Community  Post_Slab  No_Of_Posts Language_Name Pincode
# ...

# %%
data['Circle'].value_counts()
# Out:
# Circle
# Uttar Pradesh Circle       4524
# Madhya Pradesh Circle      3974
# Tamilnadu Circle           3746
# Maharashtra Circle         3146
# Rajasthan Circle           2699
# Bihar Circle               2547
# West Bengal Circle         2505
# Odisha Circle              2444
# Kerala Circle              2359
# North Eastern Circle       2154
# Jharkhand Circle           2088
# Gujarat Circle             2012
# Karnataka Circle           1888
# Andhra Pradesh Circle      1351
# Chattisgarh Circle         1334
# Uttarakhand Circle         1212
# Telangana Circle            969
# Assam Circle                877
# Himachal Pradesh Circle     700
# Jammukashmir Circle         440
# Punjab Circle               385
# Haryana Circle              239
# Delhi Circle                 20
# Name: count, dtype: int64

# %%
#GRAPH PLOT USING PANDAS

# %%
import matplotlib.pyplot as plt

# %%
data['Circle'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Circle'>

# %%
data['Circle'].value_counts().head(3).plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Circle'].value_counts().head(3).plot(kind='bar')
# Out:
# <Axes: xlabel='Circle'>

# %%
data['Circle'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['Post_Slab'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
#histogram
data['Post_Slab'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myseries = data['Circle'].value_counts()

# %%
myseries
# Out:
# Circle
# Uttar Pradesh Circle       4524
# Madhya Pradesh Circle      3974
# Tamilnadu Circle           3746
# Maharashtra Circle         3146
# Rajasthan Circle           2699
# Bihar Circle               2547
# West Bengal Circle         2505
# Odisha Circle              2444
# Kerala Circle              2359
# North Eastern Circle       2154
# Jharkhand Circle           2088
# Gujarat Circle             2012
# Karnataka Circle           1888
# Andhra Pradesh Circle      1351
# Chattisgarh Circle         1334
# Uttarakhand Circle         1212
# Telangana Circle            969
# Assam Circle                877
# Himachal Pradesh Circle     700
# Jammukashmir Circle         440
# Punjab Circle               385
# Haryana Circle              239
# Delhi Circle                 20
# Name: count, dtype: int64

# %%
myseries.index
# Out:
# Index(['Uttar Pradesh Circle', 'Madhya Pradesh Circle', 'Tamilnadu Circle',
#        'Maharashtra Circle', 'Rajasthan Circle', 'Bihar Circle',
#        'West Bengal Circle', 'Odisha Circle', 'Kerala Circle',
#        'North Eastern Circle', 'Jharkhand Circle', 'Gujarat Circle',
#        'Karnataka Circle', 'Andhra Pradesh Circle', 'Chattisgarh Circle',
#        'Uttarakhand Circle', 'Telangana Circle', 'Assam Circle',
#        'Himachal Pradesh Circle', 'Jammukashmir Circle', 'Punjab Circle',
#        'Haryana Circle', 'Delhi Circle'],
#       dtype='object', name='Circle')

# %% [markdown]
# myseries.vakue

# %%
myseries.values
# Out:
# array([4524, 3974, 3746, 3146, 2699, 2547, 2505, 2444, 2359, 2154, 2088,
#        2012, 1888, 1351, 1334, 1212,  969,  877,  700,  440,  385,  239,
#          20])

# %%
#there is a code to add two index numbers but here their is no such data so i only writee the code of a ipl data set.
#data['team2'].value_counts()+data['teaam2'].value_counts()
#to write the sum datas in decending order
#(data['team2'].value_counts()+data['teaam2'].value_counts()).sort_values(ascending =false)
#for more infermation see tthe video number 9

# %%
data
# Out:
#                       Circle                 Division                 Office  \
# 0      Andhra Pradesh Circle      Amalapuram Division     Antarvedipalem S.O
# 1      Andhra Pradesh Circle      Amalapuram Division  Appanaramunilanka B.O
# 2      Andhra Pradesh Circle      Amalapuram Division        Atreyapuram S.O
# 3      Andhra Pradesh Circle      Amalapuram Division        Balusutippa B.O
# 4      Andhra Pradesh Circle      Amalapuram Division       Battucheruvu B.O
# ...                      ...                      ...                    ...
# 43608     West Bengal Circle  Uttar Dinajpur Division              Tarial BO
# 43609     West Bengal Circle  Uttar Dinajpur Division          Thakurbari BO
# 43610     West Bengal Circle  Uttar Dinajpur Division          Thakurbari BO
# 43611     West Bengal Circle  Uttar Dinajpur Division     Tungail Bilpara BO
# 43612     West Bengal Circle  Uttar Dinajpur Division          Tungidighi BO
#
# ...

# %%
data.drop_duplicates(subset = ['Circle'])
# Out:
#                         Circle                  Division               Office  \
# 0        Andhra Pradesh Circle       Amalapuram Division   Antarvedipalem S.O
# 1351              Assam Circle           Cachar Division            Amala B.O
# 2228              Bihar Circle  AurangabadBihar Division           Abgila B.O
# 4775        Chattisgarh Circle           Bastar Division               Aadnar
# 6109              Delhi Circle      Delhi North Division           Khampur BO
# 6129            Gujarat Circle   Ahmedabad City Division            Aslali SO
# 8141            Haryana Circle           Ambala Division      Ambala City H.O
# 8380   Himachal Pradesh Circle           Chamba Division           Almi (132)
# 9080       Jammukashmir Circle        Baramulla Division           Aloosa S.O
# 9520          Jharkhand Circle        B.Deoghar Division    Amba Jarowadih BO
# 11608         Karnataka Circle         Bagalkot Division            Albal B.O
# ...

# %%
data.drop_duplicates(subset = ['Circle']).shape
# Out:
# (23, 9)

# %%
data.shape
# Out:
# (43613, 9)

# %%
data.drop_duplicates('Circle',keep ='last')[['Post','Pincode']]
# Out:
#            Post Pincode
# 1350       ABPM  535145
# 2227       ABPM  786181
# 4774        BPM  845450
# 6108       ABPM  497773
# 6128        BPM  110045
# 8140        BPM  396230
# 8379       ABPM  131028
# 9079   Daksevak  174303
# 9519        BPM  182301
# 11607       BPM  833104
# 13495       BPM  585315
# 15854      ABPM  673506
# 19828       BPM  464114
# 22974      ABPM  445402
# 25128  Daksevak  798620
# 27572      ABPM  768221
# 27957       BPM  148102
# 30656  Daksevak  313901
# 34402      ABPM  606001
# 35371       BPM  506222
# 39895  Daksevak  221003
# 41107      ABPM  249193
# 43612       BPM  733215

# %%
offices = data.groupby('Office')

# %%
len(offices)
# Out:
# 36705

# %%
offices.size().sort_values(ascending = False)
# Out:
# Office
# Narayanpur BO         20
# Rampur BO             16
# Raipur BO             16
# Rampur B.O            13
# Shahpur BO            13
#                       ..
# khodahar BO            1
# konra BO               1
# pangchou B.O           1
# wadegaon B.O           1
# Zinzavadar Nana BO     1
# Length: 36705, dtype: int64

# %%
offices.groups
# Out:
# {' Benti BO': [10056], ' Bhatuakura (Tola Gurarbaj)': [9792, 9793], ' Chanpi Khurd': [10279, 10280], ' Jankia S.O': [25592], ' Kolhaukala BO': [10057], ' Lengwa BO': [10058], ' Margarah BO': [10059], ' Pannemara B.O': [20220], ' Peddavenkatapuram B.O': [34683], ' Petadari BO': [10060], ' Tarapdanda': [11180], '1 Ap': [30227], '1 Do': [30228], '1 Sm B.O': [30229], '11 As': [30230], '13ff B.O': [30231, 30232], '15blda B.O': [30233], '16ps B.O': [30234], '1700 Chain PWD Camp': [23067, 23068], '173 K.M. Point': [23069, 23070], '18th Mile Camp': [23071, 23072], '19 F B.O': [30235], '19 Z B.O': [30236], '2 Gbm': [30237], '2 Gmb B.O': [30238], '2 K M B.O': [30239], '2 No Bokanala B.O': [1574], '2,3 Rjm': [30240], '20th Mile (Chailiang)': [23073, 23074], '29 As-B': [30241], '2a B.O': [30242], '3 F D M B.O': [30243], '3 Jkm': [30244], '3 No Borbil B.O': [2169], '30 Apd': [30245], '31ml B.O': [30246], '35 Bb B.O': [30247], '37 Ps': [30248], '38 Pbn': [30249], '40 K.M. Camp': [23075], '41 Ps B.
# ...

# %%
offices.get_group('Benti BO')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 offices.get_group('Benti BO')
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1112 inds = self._get_index(name)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#    1117     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 'Benti BO'

# %%
data2 = pd.read_csv('IPL Matches 2008-2020.csv')

# %%
data2
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore   4/18/2008     BB McCullum
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 2     335984       Delhi   4/19/2008     MF Maharoof
# 3     335985      Mumbai   4/20/2008      MV Boucher
# 4     335986     Kolkata   4/20/2008       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai   9/28/2020  AB de Villiers
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 813  1237178   Abu Dhabi   11/6/2020   KS Williamson
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
# 815  1237181       Dubai  11/10/2020        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
win = data2.groupby('winner')

# %%
win.get_group('Mumbai Indians').shape
# Out:
# (120, 17)

# %%
win.get_group('Mumbai Indians')
# Out:
#           id       city        date player_of_match  \
# 15    335997    Kolkata   4/29/2008   ST Jayasuriya
# 22    336004     Mumbai    5/4/2008      SM Pollock
# 26    336008     Mumbai    5/7/2008         A Nehra
# 30    336012  Bangalore   5/28/2008    CRD Fernando
# 36    336018     Mumbai   5/14/2008   ST Jayasuriya
# ..       ...        ...         ...             ...
# 793  1216529  Abu Dhabi  10/11/2020       Q de Kock
# 799  1216535      Dubai  10/31/2020    Ishan Kishan
# 802  1216538    Sharjah   10/4/2020        TA Boult
# 812  1237177      Dubai   11/5/2020       JJ Bumrah
# 815  1237181      Dubai  11/10/2020        TA Boult
#
#                                    venue  neutral_venue  \
# 15                          Eden Gardens              0
# 22            Dr DY Patil Sports Academy              0
# 26            Dr DY Patil Sports Academy              0
# 30                 M Chinnaswamy Stadium              0
# ...

# %%
sums = win['result_margin'].sum()

# %%
sums
# Out:
# winner
# Chennai Super Kings            2125.0
# Deccan Chargers                 493.0
# Delhi Capitals                  329.0
# Delhi Daredevils                950.0
# Gujarat Lions                    66.0
# Kings XI Punjab                1323.0
# Kochi Tuskers Kerala             53.0
# Kolkata Knight Riders          1612.0
# Mumbai Indians                 2460.0
# Pune Warriors                   175.0
# Rajasthan Royals               1215.0
# Rising Pune Supergiant          154.0
# Rising Pune Supergiants          73.0
# Royal Challengers Bangalore    1718.0
# Sunrisers Hyderabad            1094.0
# Name: result_margin, dtype: float64

# %%
sums.sort_values(ascending = False)
# Out:
# winner
# Mumbai Indians                 2460.0
# Chennai Super Kings            2125.0
# Royal Challengers Bangalore    1718.0
# Kolkata Knight Riders          1612.0
# Kings XI Punjab                1323.0
# Rajasthan Royals               1215.0
# Sunrisers Hyderabad            1094.0
# Delhi Daredevils                950.0
# Deccan Chargers                 493.0
# Delhi Capitals                  329.0
# Pune Warriors                   175.0
# Rising Pune Supergiant          154.0
# Rising Pune Supergiants          73.0
# Gujarat Lions                    66.0
# Kochi Tuskers Kerala             53.0
# Name: result_margin, dtype: float64

# %%
sums.sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='winner'>

# %%
mask = data2['result_margin']>15
new_winner = data2[mask]

# %%
new_winner
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore   4/18/2008     BB McCullum
# 1     335983  Chandigarh   4/19/2008      MEK Hussey
# 9     335991  Chandigarh   4/25/2008   KC Sangakkara
# 18    336000      Jaipur    5/1/2008     SA Asnodkar
# 22    336004      Mumbai    5/4/2008      SM Pollock
# ..       ...         ...         ...             ...
# 803  1216539       Dubai   9/25/2020         PP Shaw
# 804  1216540     Sharjah  10/12/2020  AB de Villiers
# 806  1216542       Dubai   10/8/2020     JM Bairstow
# 812  1237177       Dubai   11/5/2020       JJ Bumrah
# 814  1237180   Abu Dhabi   11/8/2020      MP Stoinis
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 9    Punjab Cricket Association Stadium, Mohali              0
# 18                       Sawai Mansingh Stadium              0
# ...

# %%
new_winner.shape
# Out:
# (231, 17)

# %%
new_winner.groupby('winner')['result_margin'].count()
# Out:
# winner
# Chennai Super Kings            36
# Deccan Chargers                 9
# Delhi Capitals                  8
# Delhi Daredevils               13
# Kings XI Punjab                21
# Kochi Tuskers Kerala            1
# Kolkata Knight Riders          29
# Mumbai Indians                 45
# Pune Warriors                   5
# Rajasthan Royals               19
# Rising Pune Supergiant          3
# Rising Pune Supergiants         2
# Royal Challengers Bangalore    23
# Sunrisers Hyderabad            17
# Name: result_margin, dtype: int64

# %%
wining = data2[data2["winner"]=='Mumbai Indians']

# %%
total_team = data2['team1']+data2['team2']

# %%
total_team
# Out:
# 0      Royal Challengers BangaloreKolkata Knight Riders
# 1                    Kings XI PunjabChennai Super Kings
# 2                      Delhi DaredevilsRajasthan Royals
# 3             Mumbai IndiansRoyal Challengers Bangalore
# 4                  Kolkata Knight RidersDeccan Chargers
#                              ...
# 811           Royal Challengers BangaloreMumbai Indians
# 812                        Mumbai IndiansDelhi Capitals
# 813      Royal Challengers BangaloreSunrisers Hyderabad
# 814                   Delhi CapitalsSunrisers Hyderabad
# 815                        Delhi CapitalsMumbai Indians
# Length: 816, dtype: object

# %%
total_unique = total_team.drop_duplicates()

# %%
total_unique
# Out:
# 0      Royal Challengers BangaloreKolkata Knight Riders
# 1                    Kings XI PunjabChennai Super Kings
# 2                      Delhi DaredevilsRajasthan Royals
# 3             Mumbai IndiansRoyal Challengers Bangalore
# 4                  Kolkata Knight RidersDeccan Chargers
#                              ...
# 732                       Delhi CapitalsKings XI Punjab
# 735                      Rajasthan RoyalsDelhi Capitals
# 741           Delhi CapitalsRoyal Challengers Bangalore
# 745                   Chennai Super KingsDelhi Capitals
# 748                      Delhi CapitalsRajasthan Royals
# Length: 156, dtype: object

# %%
wining.groupby('team1')['result_margin'].sum().sort_values(ascending = False)
# Out:
# team1
# Mumbai Indians                 1203.0
# Kolkata Knight Riders           270.0
# Delhi Daredevils                252.0
# Royal Challengers Bangalore     170.0
# Chennai Super Kings             154.0
# Deccan Chargers                 108.0
# Kings XI Punjab                  81.0
# Rajasthan Royals                 72.0
# Delhi Capitals                   59.0
# Sunrisers Hyderabad              56.0
# Pune Warriors                    27.0
# Rising Pune Supergiants           8.0
# Gujarat Lions                     0.0
# Name: result_margin, dtype: float64

# %%
def total_margin(team_name):
    wining = data2[data2["winner"]== team_name]
    return wining.groupby('team1')['result_margin'].sum().sort_values(ascending = False)

# %%
total_margin('Mumbai Indians')
# Out:
# team1
# Mumbai Indians                 1203.0
# Kolkata Knight Riders           270.0
# Delhi Daredevils                252.0
# Royal Challengers Bangalore     170.0
# Chennai Super Kings             154.0
# Deccan Chargers                 108.0
# Kings XI Punjab                  81.0
# Rajasthan Royals                 72.0
# Delhi Capitals                   59.0
# Sunrisers Hyderabad              56.0
# Pune Warriors                    27.0
# Rising Pune Supergiants           8.0
# Gujarat Lions                     0.0
# Name: result_margin, dtype: float64

# %%
#isin()

# %%
all_teams =data2.groupby("winner")['toss_winner'].count() 
x = all_teams>70
all_teams[x].index.tolist()
# Out:
# ['Chennai Super Kings',
#  'Kings XI Punjab',
#  'Kolkata Knight Riders',
#  'Mumbai Indians',
#  'Rajasthan Royals',
#  'Royal Challengers Bangalore']

# %%
#see the video 13 carefully

# %%
data3 = pd.read_csv('innings_deliveries.csv')

# %%
data3
# Out:
#                             team  over         batter          bowler  \
# 0    Royal Challengers Bengaluru     0        V Kohli        I Sharma
# 1    Royal Challengers Bengaluru     0        V Kohli        I Sharma
# 2    Royal Challengers Bengaluru     0   F du Plessis        I Sharma
# 3    Royal Challengers Bengaluru     0        V Kohli        I Sharma
# 4    Royal Challengers Bengaluru     0        V Kohli        I Sharma
# ..                           ...   ...            ...             ...
# 242               Delhi Capitals    18  Kuldeep Yadav  Mohammed Siraj
# 243               Delhi Capitals    18       I Sharma  Mohammed Siraj
# 244               Delhi Capitals    18       I Sharma  Mohammed Siraj
# 245               Delhi Capitals    18       I Sharma  Mohammed Siraj
# 246               Delhi Capitals    19  Kuldeep Yadav      Yash Dayal
#
#        non_striker  runs_batter  runs_extras  runs_total     player_out  \
# ...

# %%
# #merge
# data3.merge()

# %%
#in video 15v we learn pivort table

# %%
data.corr(numeric_only = True)
# Out:
#              Post_Slab  No_Of_Posts
# Post_Slab     1.000000    -0.083784
# No_Of_Posts  -0.083784     1.000000

# %%
#rename columns
data.rename(columns = {'Circle':'circle'},inplace = True)

# %%
data
# Out:
#                       circle                 Division                 Office  \
# 0      Andhra Pradesh Circle      Amalapuram Division     Antarvedipalem S.O
# 1      Andhra Pradesh Circle      Amalapuram Division  Appanaramunilanka B.O
# 2      Andhra Pradesh Circle      Amalapuram Division        Atreyapuram S.O
# 3      Andhra Pradesh Circle      Amalapuram Division        Balusutippa B.O
# 4      Andhra Pradesh Circle      Amalapuram Division       Battucheruvu B.O
# ...                      ...                      ...                    ...
# 43608     West Bengal Circle  Uttar Dinajpur Division              Tarial BO
# 43609     West Bengal Circle  Uttar Dinajpur Division          Thakurbari BO
# 43610     West Bengal Circle  Uttar Dinajpur Division          Thakurbari BO
# 43611     West Bengal Circle  Uttar Dinajpur Division     Tungail Bilpara BO
# 43612     West Bengal Circle  Uttar Dinajpur Division          Tungidighi BO
#
# ...

# %%
data.set_index()
